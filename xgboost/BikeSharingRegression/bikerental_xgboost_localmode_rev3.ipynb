# %% [markdown]
# ## Train a model with bike rental data using XGBoost algorithm
# ### Training log1p(count) dataset
# ###  Model is trained with XGBoost installed in notebook instance
# ###  In the later examples, we will train using SageMaker's XGBoost algorithm

# %%
# Install xgboost in notebook instance.
#### Command to install xgboost
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /home/vscode/.local/lib/python3.10/site-packages (3.0.2)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/vscode/.local/lib/python3.10/site-packages (from xgboost) (2.26.5)
# Requirement already satisfied: scipy in /home/vscode/.local/lib/python3.10/site-packages (from xgboost) (1.15.3)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 45.5 MB/s eta 0:00:00:00:01
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.1 scikit-learn-1.6.1 threadpoolctl-3.6.0

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error

# XGBoost 
import xgboost as xgb

# %%
column_list_file = 'bike_train_column_list.txt'
train_file = 'bike_train.csv'
validation_file = 'bike_validation.csv'
test_file = 'bike_test.csv'

# %%
columns = ''
with open(column_list_file,'r') as f:
    columns = f.read().split(',')

# %%
columns
# Out:
# ['count',
#  'season',
#  'holiday',
#  'workingday',
#  'weather',
#  'temp',
#  'atemp',
#  'humidity',
#  'windspeed',
#  'year',
#  'month',
#  'day',
#  'dayofweek',
#  'hour']

# %%
# Specify the column names as the file does not have column header
df_train = pd.read_csv(train_file,names=columns)
df_validation = pd.read_csv(validation_file,names=columns)

# %%
df_train.head()
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0  4.477337       3        0           0        2  26.24  30.305        73
# 1  5.517453       3        0           1        1  32.80  34.850        33
# 2  5.814131       4        0           0        1  15.58  19.695        40
# 3  6.436150       3        0           1        1  32.80  37.880        55
# 4  4.262680       2        0           1        1  13.94  17.425        76
#
#    windspeed  year  month  day  dayofweek  hour
# 0     7.0015  2011      9    3          5     0
# 1     7.0015  2012      8   13          0    14
# 2    11.0014  2011     11    5          5    17
# 3    12.9980  2012      8    9          3    19
# 4     7.0015  2011      4   14          3     6

# %%
df_validation.head()
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0  6.095825       3        0           1        2  28.70  33.335        79
# 1  5.961005       2        0           0        1  32.80  37.880        55
# 2  1.098612       1        0           1        1  14.76  16.665        40
# 3  3.891820       1        0           1        1   9.02   9.090        47
# 4  4.025352       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
X_train = df_train.iloc[:,1:] # Features: 1st column onwards 
y_train = df_train.iloc[:,0].ravel() # Target: 0th column

X_validation = df_validation.iloc[:,1:]
y_validation = df_validation.iloc[:,0].ravel()
# Out:
# /tmp/ipykernel_20771/2629520565.py:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_train = df_train.iloc[:,0].ravel() # Target: 0th column
# /tmp/ipykernel_20771/2629520565.py:5: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_validation = df_validation.iloc[:,0].ravel()

# %%
# XGBoost Training Parameter Reference: 
#   https://github.com/dmlc/xgboost/blob/master/doc/parameter.md
#regressor = xgb.XGBRegressor(max_depth=5,eta=0.1,subsample=0.7,num_round=150)
regressor = xgb.XGBRegressor(max_depth=5,n_estimators=150)

# %%
regressor
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=150,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
regressor.fit(X_train,y_train, eval_set = [(X_train, y_train), (X_validation, y_validation)])
# Out:
# [0]	validation_0-rmse:1.09526	validation_1-rmse:1.07167
# [1]	validation_0-rmse:0.86855	validation_1-rmse:0.85094
# [2]	validation_0-rmse:0.71852	validation_1-rmse:0.70620
# [3]	validation_0-rmse:0.61078	validation_1-rmse:0.60450
# [4]	validation_0-rmse:0.53109	validation_1-rmse:0.53023
# [5]	validation_0-rmse:0.47017	validation_1-rmse:0.47573
# [6]	validation_0-rmse:0.43944	validation_1-rmse:0.44969
# [7]	validation_0-rmse:0.42017	validation_1-rmse:0.43368
# [8]	validation_0-rmse:0.39699	validation_1-rmse:0.41308
# [9]	validation_0-rmse:0.37165	validation_1-rmse:0.39090
# [10]	validation_0-rmse:0.36265	validation_1-rmse:0.38352
# [11]	validation_0-rmse:0.34992	validation_1-rmse:0.37414
# [12]	validation_0-rmse:0.33666	validation_1-rmse:0.36241
# [13]	validation_0-rmse:0.32912	validation_1-rmse:0.35733
# [14]	validation_0-rmse:0.32212	validation_1-rmse:0.35159
# [15]	validation_0-rmse:0.31083	validation_1-rmse:0.34112
# [16]	validation_0-rmse:0.30835	validation_1-rmse:0.34033
# [17]	validation_0-rmse:0.30602	validation_1-rmse:0.33933
# [18]	validation_0-rmse:0.30387	validation_1-rmse:0.33847
# [19]	validation_0-rmse:0.29886	validation_1-rmse:0.33488
# [20]	validation_0-rmse:0.29058	validation_1-rmse:0.32647
# [21]	validation_0-rmse:0.28832	validation_1-rmse:0.32597
# [22]	validation_0-rmse:0.28559	validation_1-rmse:0.32388
# [23]	validation_0-rmse:0.28246	validation_1-rmse:0.32134
# [24]	validation_0-rmse:0.27737	validation_1-rmse:0.31732
# [25]	validation_0-rmse:0.27602	validation_1-rmse:0.31698
# [26]	validation_0-rmse:0.27308	validation_1-rmse:0.31553
# [27]	validation_0-rmse:0.27150	validation_1-rmse:0.31423
# [28]	validation_0-rmse:0.26955	validation_1-rmse:0.31308
# [29]	validation_0-rmse:0.26834	validation_1-rmse:0.31241
# [30]	validation_0-rmse:0.26554	validation_1-rmse:0.31037
# [31]	validation_0-rmse:0.26265	validation_1-rmse:0.30848
# [32]	validation_0-rmse:0.26118	validation_1-rmse:0.30800
# [33]	validation_0-rmse:0.25870	validation_1-rmse:0.30658
# [34]	validation_0-rmse:0.25677	validation_1-rmse:0.30545
# [35]	validation_0-rmse:0.25530	validation_1-rmse:0.30434
# [36]	validation_0-rmse:0.25450	validation_1-rmse:0.30373
# [37]	validation_0-rmse:0.25328	validation_1-rmse:0.30344
# [38]	validation_0-rmse:0.25237	validation_1-rmse:0.30353
# [39]	validation_0-rmse:0.25076	validation_1-rmse:0.30267
# [40]	validation_0-rmse:0.25055	validation_1-rmse:0.30271
# [41]	validation_0-rmse:0.24941	validation_1-rmse:0.30168
# [42]	validation_0-rmse:0.24840	validation_1-rmse:0.30129
# [43]	validation_0-rmse:0.24730	validation_1-rmse:0.30084
# [44]	validation_0-rmse:0.24575	validation_1-rmse:0.30035
# [45]	validation_0-rmse:0.24500	validation_1-rmse:0.30052
# [46]	validation_0-rmse:0.24335	validation_1-rmse:0.29998
# [47]	validation_0-rmse:0.24163	validation_1-rmse:0.30050
# [48]	validation_0-rmse:0.24049	validation_1-rmse:0.29999
# [49]	validation_0-rmse:0.23808	validation_1-rmse:0.29837
# [50]	validation_0-rmse:0.23738	validation_1-rmse:0.29811
# [51]	validation_0-rmse:0.23609	validation_1-rmse:0.29754
# [52]	validation_0-rmse:0.23463	validation_1-rmse:0.29795
# [53]	validation_0-rmse:0.23351	validation_1-rmse:0.29793
# [54]	validation_0-rmse:0.23246	validation_1-rmse:0.29793
# [55]	validation_0-rmse:0.23234	validation_1-rmse:0.29791
# [56]	validation_0-rmse:0.23228	validation_1-rmse:0.29795
# [57]	validation_0-rmse:0.23076	validation_1-rmse:0.29795
# [58]	validation_0-rmse:0.22999	validation_1-rmse:0.29742
# [59]	validation_0-rmse:0.22863	validation_1-rmse:0.29749
# [60]	validation_0-rmse:0.22789	validation_1-rmse:0.29731
# [61]	validation_0-rmse:0.22742	validation_1-rmse:0.29722
# [62]	validation_0-rmse:0.22718	validation_1-rmse:0.29720
# [63]	validation_0-rmse:0.22645	validation_1-rmse:0.29722
# [64]	validation_0-rmse:0.22563	validation_1-rmse:0.29681
# [65]	validation_0-rmse:0.22442	validation_1-rmse:0.29634
# [66]	validation_0-rmse:0.22368	validation_1-rmse:0.29618
# [67]	validation_0-rmse:0.22258	validation_1-rmse:0.29563
# [68]	validation_0-rmse:0.22148	validation_1-rmse:0.29544
# [69]	validation_0-rmse:0.22114	validation_1-rmse:0.29546
# [70]	validation_0-rmse:0.22037	validation_1-rmse:0.29506
# [71]	validation_0-rmse:0.21949	validation_1-rmse:0.29515
# [72]	validation_0-rmse:0.21897	validation_1-rmse:0.29521
# [73]	validation_0-rmse:0.21796	validation_1-rmse:0.29507
# [74]	validation_0-rmse:0.21762	validation_1-rmse:0.29522
# [75]	validation_0-rmse:0.21732	validation_1-rmse:0.29539
# [76]	validation_0-rmse:0.21661	validation_1-rmse:0.29519
# [77]	validation_0-rmse:0.21474	validation_1-rmse:0.29420
# [78]	validation_0-rmse:0.21342	validation_1-rmse:0.29437
# [79]	validation_0-rmse:0.21232	validation_1-rmse:0.29425
# [80]	validation_0-rmse:0.21200	validation_1-rmse:0.29419
# [81]	validation_0-rmse:0.21165	validation_1-rmse:0.29441
# [82]	validation_0-rmse:0.21014	validation_1-rmse:0.29275
# [83]	validation_0-rmse:0.20969	validation_1-rmse:0.29245
# [84]	validation_0-rmse:0.20895	validation_1-rmse:0.29242
# [85]	validation_0-rmse:0.20807	validation_1-rmse:0.29246
# [86]	validation_0-rmse:0.20734	validation_1-rmse:0.29247
# [87]	validation_0-rmse:0.20648	validation_1-rmse:0.29212
# [88]	validation_0-rmse:0.20612	validation_1-rmse:0.29175
# [89]	validation_0-rmse:0.20531	validation_1-rmse:0.29159
# [90]	validation_0-rmse:0.20484	validation_1-rmse:0.29148
# [91]	validation_0-rmse:0.20372	validation_1-rmse:0.29081
# [92]	validation_0-rmse:0.20330	validation_1-rmse:0.29046
# [93]	validation_0-rmse:0.20248	validation_1-rmse:0.29034
# [94]	validation_0-rmse:0.20113	validation_1-rmse:0.28970
# [95]	validation_0-rmse:0.20062	validation_1-rmse:0.28991
# [96]	validation_0-rmse:0.20032	validation_1-rmse:0.28993
# [97]	validation_0-rmse:0.20011	validation_1-rmse:0.28998
# [98]	validation_0-rmse:0.19943	validation_1-rmse:0.28997
# [99]	validation_0-rmse:0.19864	validation_1-rmse:0.28968
# [100]	validation_0-rmse:0.19793	validation_1-rmse:0.28981
# [101]	validation_0-rmse:0.19706	validation_1-rmse:0.28980
# [102]	validation_0-rmse:0.19658	validation_1-rmse:0.28975
# [103]	validation_0-rmse:0.19648	validation_1-rmse:0.28977
# [104]	validation_0-rmse:0.19637	validation_1-rmse:0.28973
# [105]	validation_0-rmse:0.19570	validation_1-rmse:0.28961
# [106]	validation_0-rmse:0.19512	validation_1-rmse:0.28978
# [107]	validation_0-rmse:0.19503	validation_1-rmse:0.28977
# [108]	validation_0-rmse:0.19458	validation_1-rmse:0.29031
# [109]	validation_0-rmse:0.19336	validation_1-rmse:0.28998
# [110]	validation_0-rmse:0.19253	validation_1-rmse:0.29002
# [111]	validation_0-rmse:0.19204	validation_1-rmse:0.29015
# [112]	validation_0-rmse:0.19102	validation_1-rmse:0.28991
# [113]	validation_0-rmse:0.19019	validation_1-rmse:0.28997
# [114]	validation_0-rmse:0.18958	validation_1-rmse:0.28991
# [115]	validation_0-rmse:0.18924	validation_1-rmse:0.29000
# [116]	validation_0-rmse:0.18863	validation_1-rmse:0.28991
# [117]	validation_0-rmse:0.18798	validation_1-rmse:0.29021
# [118]	validation_0-rmse:0.18709	validation_1-rmse:0.29041
# [119]	validation_0-rmse:0.18627	validation_1-rmse:0.29036
# [120]	validation_0-rmse:0.18560	validation_1-rmse:0.29009
# [121]	validation_0-rmse:0.18505	validation_1-rmse:0.29005
# [122]	validation_0-rmse:0.18450	validation_1-rmse:0.28997
# [123]	validation_0-rmse:0.18426	validation_1-rmse:0.28996
# [124]	validation_0-rmse:0.18370	validation_1-rmse:0.29014
# [125]	validation_0-rmse:0.18339	validation_1-rmse:0.29017
# [126]	validation_0-rmse:0.18278	validation_1-rmse:0.28981
# [127]	validation_0-rmse:0.18216	validation_1-rmse:0.28966
# [128]	validation_0-rmse:0.18160	validation_1-rmse:0.28988
# [129]	validation_0-rmse:0.18108	validation_1-rmse:0.28989
# [130]	validation_0-rmse:0.18104	validation_1-rmse:0.28987
# [131]	validation_0-rmse:0.18024	validation_1-rmse:0.28979
# [132]	validation_0-rmse:0.17949	validation_1-rmse:0.28965
# [133]	validation_0-rmse:0.17899	validation_1-rmse:0.28946
# [134]	validation_0-rmse:0.17850	validation_1-rmse:0.28929
# [135]	validation_0-rmse:0.17808	validation_1-rmse:0.28936
# [136]	validation_0-rmse:0.17766	validation_1-rmse:0.28928
# [137]	validation_0-rmse:0.17711	validation_1-rmse:0.28922
# [138]	validation_0-rmse:0.17663	validation_1-rmse:0.28909
# [139]	validation_0-rmse:0.17658	validation_1-rmse:0.28913
# [140]	validation_0-rmse:0.17600	validation_1-rmse:0.28933
# [141]	validation_0-rmse:0.17563	validation_1-rmse:0.28927
# [142]	validation_0-rmse:0.17514	validation_1-rmse:0.28931
# [143]	validation_0-rmse:0.17478	validation_1-rmse:0.28936
# [144]	validation_0-rmse:0.17419	validation_1-rmse:0.28924
# [145]	validation_0-rmse:0.17404	validation_1-rmse:0.28917
# [146]	validation_0-rmse:0.17348	validation_1-rmse:0.28914
# [147]	validation_0-rmse:0.17340	validation_1-rmse:0.28923
# [148]	validation_0-rmse:0.17307	validation_1-rmse:0.28909
# [149]	validation_0-rmse:0.17251	validation_1-rmse:0.28920
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=150,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
df_train['count'].describe()
# Out:
# count    7620.000000
# mean        4.583886
# std         1.429959
# min         0.693147
# 25%         3.737670
# 50%         4.976734
# 75%         5.652489
# max         6.885510
# Name: count, dtype: float64

# %%
eval_result = regressor.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))
training_rounds
# Out:
# range(0, 150)

# %%
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.grid(True)
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
xgb.plot_importance(regressor)
plt.show()

# %%
# Updated - Changed to validation dataset
# Compare actual vs predicted performance with dataset not seen by the model before
df = pd.read_csv(validation_file,names=columns)

# %%
df.head()
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0  6.095825       3        0           1        2  28.70  33.335        79
# 1  5.961005       2        0           0        1  32.80  37.880        55
# 2  1.098612       1        0           1        1  14.76  16.665        40
# 3  3.891820       1        0           1        1   9.02   9.090        47
# 4  4.025352       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
X_test = df.iloc[:,1:]
print(X_test[:5])
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       3        0           1        2  28.70  33.335        79    12.9980
# 1       2        0           0        1  32.80  37.880        55    12.9980
# 2       1        0           1        1  14.76  16.665        40    19.9995
# 3       1        0           1        1   9.02   9.090        47    36.9974
# 4       4        0           0        1  10.66  15.150        87     0.0000
#
#    year  month  day  dayofweek  hour
# 0  2011      7    7          3     8
# 1  2011      6   11          5    13
# 2  2011      2   14          0     2
# 3  2011      2    8          1    10
# 4  2011     12    4          6     8

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([6.053212 , 5.9359384, 1.3226197, 4.0439215, 4.2267604],
#       dtype=float32)

# %%
df.head()
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0  6.095825       3        0           1        2  28.70  33.335        79
# 1  5.961005       2        0           0        1  32.80  37.880        55
# 2  1.098612       1        0           1        1  14.76  16.665        40
# 3  3.891820       1        0           1        1   9.02   9.090        47
# 4  4.025352       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour
# 0    12.9980  2011      7    7          3     8
# 1    12.9980  2011      6   11          5    13
# 2    19.9995  2011      2   14          0     2
# 3    36.9974  2011      2    8          1    10
# 4     0.0000  2011     12    4          6     8

# %%
df['count_predicted'] = result

# %%
df.head()
# Out:
#       count  season  holiday  workingday  weather   temp   atemp  humidity  \
# 0  6.095825       3        0           1        2  28.70  33.335        79
# 1  5.961005       2        0           0        1  32.80  37.880        55
# 2  1.098612       1        0           1        1  14.76  16.665        40
# 3  3.891820       1        0           1        1   9.02   9.090        47
# 4  4.025352       4        0           0        1  10.66  15.150        87
#
#    windspeed  year  month  day  dayofweek  hour  count_predicted
# 0    12.9980  2011      7    7          3     8         6.053212
# 1    12.9980  2011      6   11          5    13         5.935938
# 2    19.9995  2011      2   14          0     2         1.322620
# 3    36.9974  2011      2    8          1    10         4.043921
# 4     0.0000  2011     12    4          6     8         4.226760

# %%
# Negative Values are predicted
df['count_predicted'].describe()
# Out:
# count    3266.000000
# mean        4.594542
# std         1.378380
# min         0.497854
# 25%         3.775636
# 50%         4.979265
# 75%         5.617390
# max         6.854691
# Name: count_predicted, dtype: float64

# %%
df[df['count_predicted'] < 0]
# Out:
# Empty DataFrame
# Columns: [count, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, year, month, day, dayofweek, hour, count_predicted]
# Index: []

# %%
def adjust_count(x):
    if x < 0:
        return 0
    else:
        return x

# %%
df['count_predicted'] = df['count_predicted'].map(adjust_count)

# %%
df[df['count_predicted'] < 0]
# Out:
# Empty DataFrame
# Columns: [count, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, year, month, day, dayofweek, hour, count_predicted]
# Index: []

# %%
df['count'] = df['count'].map(np.expm1)
df['count_predicted'] = df['count_predicted'].map(np.expm1)

# %%
# Actual Vs Predicted
plt.plot(df['count'], label='Actual')
plt.plot(df['count_predicted'],label='Predicted')
plt.xlabel('Sample')
plt.ylabel('Count')
plt.xlim([100,150])
plt.title('Validation Dataset - Predicted Vs. Actual')
plt.legend()
plt.show()

# %%
# Over prediction and Under Prediction needs to be balanced
# Training Data Residuals
residuals = (df['count'] - df['count_predicted'])

plt.hist(residuals)
plt.grid(True)
plt.xlabel('Actual - Predicted')
plt.ylabel('Count')
plt.title('Residuals Distribution')
plt.axvline(color='r')
plt.show()

# %%
value_counts = (residuals > 0).value_counts(sort=False)
print(' Under Estimation: {0:.2f}'.format(value_counts[True]/len(residuals)))
print(' Over  Estimation: {0:.2f}'.format(value_counts[False]/len(residuals)))
# Out:
#  Under Estimation: 0.54
#  Over  Estimation: 0.46

# %%
import sklearn.metrics as metrics
print("RMSE: {0:.2f}".format(metrics.mean_squared_error(df['count'],
                                                    df['count_predicted'])**.5))
# Out:
# RMSE: 42.32

# %%
# Metric Use By Kaggle
def compute_rmsle(y_true, y_pred):
    if type(y_true) != np.ndarray:
        y_true = np.array(y_true)
        
    if type(y_pred) != np.ndarray:
        y_pred = np.array(y_pred)
     
    return(np.average((np.log1p(y_pred) - np.log1p(y_true))**2)**.5)

# %%
print("RMSLE: {0:.2f}".format(compute_rmsle(df['count'],df['count_predicted'])))
# Out:
# RMSLE: 0.29

# %%
# Prepare Data for Submission to Kaggle
df_test = pd.read_csv(test_file,parse_dates=['datetime'])

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour
# 0        56    26.0027  2011      1   20          3     0
# 1        56     0.0000  2011      1   20          3     1
# 2        56     0.0000  2011      1   20          3     2
# 3        56    11.0014  2011      1   20          3     3
# 4        56    11.0014  2011      1   20          3     4

# %%
X_test =  df_test.iloc[:,1:] # Exclude datetime for prediction

# %%
X_test.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    year  month  day  dayofweek  hour
# 0  2011      1   20          3     0
# 1  2011      1   20          3     1
# 2  2011      1   20          3     2
# 3  2011      1   20          3     3
# 4  2011      1   20          3     4

# %%
result = regressor.predict(X_test)

# %%
result[:5]
# Out:
# array([2.178234  , 1.8829607 , 1.6226288 , 0.95476675, 0.79331774],
#       dtype=float32)

# %%
np.expm1(result)
# Out:
# array([  7.8306985,   5.5729365,   4.0663915, ..., 120.21744  ,
#         90.556946 ,  54.498924 ], dtype=float32)

# %%
# Convert result to actual count
df_test["count"] = np.expm1(result)

# %%
df_test.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  year  month  day  dayofweek  hour     count
# 0        56    26.0027  2011      1   20          3     0  7.830698
# 1        56     0.0000  2011      1   20          3     1  5.572937
# 2        56     0.0000  2011      1   20          3     2  4.066391
# 3        56    11.0014  2011      1   20          3     3  1.598065
# 4        56    11.0014  2011      1   20          3     4  1.210719

# %%
df_test[df_test["count"] < 0]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, year, month, day, dayofweek, hour, count]
# Index: []

# %%
df_test[['datetime','count']].to_csv('predicted_count.csv',index=False)

# %%
# RMSLE (Kaggle) Score
# Test 1: 0.62
# Test 2(log of count): 0.40
