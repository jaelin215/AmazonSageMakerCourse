# %% [markdown]
# # Introduction to Data Formats and S3

# %%
import pandas as pd
import numpy as np

import boto3
import sagemaker.amazon.common as smac
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/codespace/.config/sagemaker/config.yaml

# %%
np.random.seed(5)

# %%
# NOTE: Specify your bucket
s3_bucket_name = 'jaelin-ml-sagemaker'

# %% [markdown]
# ## Sample DataSet
# ### Three features x1,x2,x3 and a target variable y

# %%
n = 10

x1 = np.random.random_sample(n)       # n floating point numbers between 0 and 1
x2 = np.random.randint(100,200,n)     # n integers
x3 = np.random.random_sample(n) * 10  # n floating point numbers between 0 and 10
y = np.random.randint(0,2,n)          # Response variable 0 or 1

# %%
x3
# Out:
# array([2.04154748, 1.19095357, 8.77903071, 5.2367529 , 4.92135999,
#        7.318711  , 0.14580751, 0.93363034, 8.26554249, 8.33492742])

# %%
y
# Out:
# array([0, 0, 1, 1, 1, 1, 0, 0, 0, 1])

# %%
df = pd.DataFrame({'x1':x1,
              'x2':x2, 
              'x3':x3,
              'y':y})

# %%
df
# Out:
#          x1   x2        x3  y
# 0  0.221993  153  2.041547  0
# 1  0.870732  180  1.190954  0
# 2  0.206719  127  8.779031  1
# 3  0.918611  144  5.236753  1
# 4  0.488411  177  4.921360  1
# 5  0.611744  175  7.318711  1
# 6  0.765908  165  0.145808  0
# 7  0.518418  147  0.933630  0
# 8  0.296801  130  8.265542  0
# 9  0.187721  184  8.334927  1

# %%
# Write to SageMaker Notebook Instance
df.to_csv('demo_file.csv',index=False)

# %%
# Write and Reading from S3 is just as easy
# files are referred as objects in S3.  
# file name is referred as key name in S3
# Files stored in S3 are automatically replicated across 3 different availability zones 
# in the region where the bucket was created.

# http://boto3.readthedocs.io/en/latest/guide/s3.html
def write_to_s3(filename, bucket, key):
    with open(filename,'rb') as f: # Read in binary mode
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(f)

# %%
# http://boto3.readthedocs.io/en/latest/guide/s3.html
def download_from_s3(filename, bucket, key):
    with open(filename,'wb') as f:
        return boto3.Session().resource('s3').Bucket(bucket).Object(key).download_fileobj(f)

# %%
write_to_s3('demo_file.csv', s3_bucket_name, 'data_format/demo_file.csv')
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 write_to_s3('demo_file.csv', s3_bucket_name, 'data_format/demo_file.csv')                    │
# │   2                                                                                              │
# │                                                                                                  │
# │ in write_to_s3:10                                                                                │
# │                                                                                                  │
# │    7 # http://boto3.readthedocs.io/en/latest/guide/s3.html                                       │
# │    8 def write_to_s3(filename, bucket, key):                                                     │
# │    9 │   with open(filename,'rb') as f: # Read in binary mode                                    │
# │ ❱ 10 │   │   return boto3.Session().resource('s3').Bucket(bucket).Object(key).upload_fileobj(    │
# │   11                                                                                             │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/boto3/s3/inject.py:764 in           │
# │ object_upload_fileobj                                                                            │
# │                                                                                                  │
# │   761 │   :param Config: The transfer configuration to be used when performing the               │
# │   762 │   │   upload.                                                                            │
# │   763 │   """                                                                                    │
# │ ❱ 764 │   return self.meta.client.upload_fileobj(                                                │
# │   765 │   │   Fileobj=Fileobj,                                                                   │
# │   766 │   │   Bucket=self.bucket_name,                                                           │
# │   767 │   │   Key=self.key,                                                                      │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/context.py:123 in wrapper  │
# │                                                                                                  │
# │   120 │   │   │   with start_as_current_context():                                               │
# │   121 │   │   │   │   if hook:                                                                   │
# │   122 │   │   │   │   │   hook()                                                                 │
# │ ❱ 123 │   │   │   │   return func(*args, **kwargs)                                               │
# │   124 │   │                                                                                      │
# │   125 │   │   return wrapper                                                                     │
# │   126                                                                                            │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/boto3/s3/inject.py:675 in           │
# │ upload_fileobj                                                                                   │
# │                                                                                                  │
# │   672 │   │   │   extra_args=ExtraArgs,                                                          │
# │   673 │   │   │   subscribers=subscribers,                                                       │
# │   674 │   │   )                                                                                  │
# │ ❱ 675 │   │   return future.result()                                                             │
# │   676                                                                                            │
# │   677                                                                                            │
# │   678 def bucket_upload_fileobj(                                                                 │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/s3transfer/futures.py:111 in result │
# │                                                                                                  │
# │   108 │   │   │   # Usually the result() method blocks until the transfer is done,               │
# │   109 │   │   │   # however if a KeyboardInterrupt is raised we want want to exit                │
# │   110 │   │   │   # out of this and propagate the exception.                                     │
# │ ❱ 111 │   │   │   return self._coordinator.result()                                              │
# │   112 │   │   except KeyboardInterrupt as e:                                                     │
# │   113 │   │   │   self.cancel()                                                                  │
# │   114 │   │   │   raise e                                                                        │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/s3transfer/futures.py:287 in result │
# │                                                                                                  │
# │   284 │   │   # Once done waiting, raise an exception if present or return the                   │
# │   285 │   │   # final result.                                                                    │
# │   286 │   │   if self._exception:                                                                │
# │ ❱ 287 │   │   │   raise self._exception                                                          │
# │   288 │   │   return self._result                                                                │
# │   289 │                                                                                          │
# │   290 │   def cancel(self, msg='', exc_type=CancelledError):                                     │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/s3transfer/tasks.py:142 in __call__ │
# │                                                                                                  │
# │   139 │   │   │   │   # task to the TransferFuture had failed) then execute the task's           │
# │   140 │   │   │   │   # main() method.                                                           │
# │   141 │   │   │   │   if not self._transfer_coordinator.done():                                  │
# │ ❱ 142 │   │   │   │   │   return self._execute_main(kwargs)                                      │
# │   143 │   │   │   except Exception as e:                                                         │
# │   144 │   │   │   │   self._log_and_set_exception(e)                                             │
# │   145 │   │   │   finally:                                                                       │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/s3transfer/tasks.py:165 in          │
# │ _execute_main                                                                                    │
# │                                                                                                  │
# │   162 │   │   # Log what is about to be executed.                                                │
# │   163 │   │   logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")             │
# │   164 │   │                                                                                      │
# │ ❱ 165 │   │   return_value = self._main(**kwargs)                                                │
# │   166 │   │   # If the task is the final task, then set the TransferFuture's                     │
# │   167 │   │   # value to the return value from main().                                           │
# │   168 │   │   if self._is_final:                                                                 │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/s3transfer/upload.py:796 in _main   │
# │                                                                                                  │
# │   793 │   │   │   used in the upload.                                                            │
# │   794 │   │   """                                                                                │
# │   795 │   │   with fileobj as body:                                                              │
# │ ❱ 796 │   │   │   client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)             │
# │   797                                                                                            │
# │   798                                                                                            │
# │   799 class UploadPartTask(Task):                                                                │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/client.py:595 in _api_call │
# │                                                                                                  │
# │    592 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    593 │   │   │   │   )                                                                         │
# │    594 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  595 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    596 │   │                                                                                     │
# │    597 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    598                                                                                           │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/context.py:123 in wrapper  │
# │                                                                                                  │
# │   120 │   │   │   with start_as_current_context():                                               │
# │   121 │   │   │   │   if hook:                                                                   │
# │   122 │   │   │   │   │   hook()                                                                 │
# │ ❱ 123 │   │   │   │   return func(*args, **kwargs)                                               │
# │   124 │   │                                                                                      │
# │   125 │   │   return wrapper                                                                     │
# │   126                                                                                            │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/client.py:1040 in          │
# │ _make_api_call                                                                                   │
# │                                                                                                  │
# │   1037 │   │   │   │   self.meta.config, request_dict, operation_model                           │
# │   1038 │   │   │   )                                                                             │
# │   1039 │   │   │   apply_request_checksum(request_dict)                                          │
# │ ❱ 1040 │   │   │   http, parsed_response = self._make_request(                                   │
# │   1041 │   │   │   │   operation_model, request_dict, request_context                            │
# │   1042 │   │   │   )                                                                             │
# │   1043                                                                                           │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/client.py:1064 in          │
# │ _make_request                                                                                    │
# │                                                                                                  │
# │   1061 │                                                                                         │
# │   1062 │   def _make_request(self, operation_model, request_dict, request_context):              │
# │   1063 │   │   try:                                                                              │
# │ ❱ 1064 │   │   │   return self._endpoint.make_request(operation_model, request_dict)             │
# │   1065 │   │   except Exception as e:                                                            │
# │   1066 │   │   │   self.meta.events.emit(                                                        │
# │   1067 │   │   │   │   f'after-call-error.{self._service_model.service_id.hyphenize()}.{operati  │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/endpoint.py:119 in         │
# │ make_request                                                                                     │
# │                                                                                                  │
# │   116 │   │   │   operation_model,                                                               │
# │   117 │   │   │   request_dict,                                                                  │
# │   118 │   │   )                                                                                  │
# │ ❱ 119 │   │   return self._send_request(request_dict, operation_model)                           │
# │   120 │                                                                                          │
# │   121 │   def create_request(self, params, operation_model=None):                                │
# │   122 │   │   request = create_request_object(params)                                            │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/endpoint.py:196 in         │
# │ _send_request                                                                                    │
# │                                                                                                  │
# │   193 │   │   attempts = 1                                                                       │
# │   194 │   │   context = request_dict['context']                                                  │
# │   195 │   │   self._update_retries_context(context, attempts)                                    │
# │ ❱ 196 │   │   request = self.create_request(request_dict, operation_model)                       │
# │   197 │   │   success_response, exception = self._get_response(                                  │
# │   198 │   │   │   request, operation_model, context                                              │
# │   199 │   │   )                                                                                  │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/endpoint.py:132 in         │
# │ create_request                                                                                   │
# │                                                                                                  │
# │   129 │   │   │   )                                                                              │
# │   130 │   │   │   service_id = operation_model.service_model.service_id.hyphenize()              │
# │   131 │   │   │   event_name = f'request-created.{service_id}.{operation_model.name}'            │
# │ ❱ 132 │   │   │   self._event_emitter.emit(                                                      │
# │   133 │   │   │   │   event_name,                                                                │
# │   134 │   │   │   │   request=request,                                                           │
# │   135 │   │   │   │   operation_name=operation_model.name,                                       │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/hooks.py:412 in emit       │
# │                                                                                                  │
# │   409 │                                                                                          │
# │   410 │   def emit(self, event_name, **kwargs):                                                  │
# │   411 │   │   aliased_event_name = self._alias_event_name(event_name)                            │
# │ ❱ 412 │   │   return self._emitter.emit(aliased_event_name, **kwargs)                            │
# │   413 │                                                                                          │
# │   414 │   def emit_until_response(self, event_name, **kwargs):                                   │
# │   415 │   │   aliased_event_name = self._alias_event_name(event_name)                            │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/hooks.py:256 in emit       │
# │                                                                                                  │
# │   253 │   │   :return: List of (handler, response) tuples from all processed                     │
# │   254 │   │   │   │    handlers.                                                                 │
# │   255 │   │   """                                                                                │
# │ ❱ 256 │   │   return self._emit(event_name, kwargs)                                              │
# │   257 │                                                                                          │
# │   258 │   def emit_until_response(self, event_name, **kwargs):                                   │
# │   259 │   │   """                                                                                │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/hooks.py:239 in _emit      │
# │                                                                                                  │
# │   236 │   │   responses = []                                                                     │
# │   237 │   │   for handler in handlers_to_call:                                                   │
# │   238 │   │   │   logger.debug('Event %s: calling handler %s', event_name, handler)              │
# │ ❱ 239 │   │   │   response = handler(**kwargs)                                                   │
# │   240 │   │   │   responses.append((handler, response))                                          │
# │   241 │   │   │   if stop_on_response and response is not None:                                  │
# │   242 │   │   │   │   return responses                                                           │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/signers.py:106 in handler  │
# │                                                                                                  │
# │   103 │   │   # from a client's event emitter.  When a new request is created                    │
# │   104 │   │   # this method is invoked to sign the request.                                      │
# │   105 │   │   # Don't call this method directly.                                                 │
# │ ❱ 106 │   │   return self.sign(operation_name, request)                                          │
# │   107 │                                                                                          │
# │   108 │   def sign(                                                                              │
# │   109 │   │   self,                                                                              │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/signers.py:198 in sign     │
# │                                                                                                  │
# │   195 │   │   │   │   else:                                                                      │
# │   196 │   │   │   │   │   raise e                                                                │
# │   197 │   │   │                                                                                  │
# │ ❱ 198 │   │   │   auth.add_auth(request)                                                         │
# │   199 │                                                                                          │
# │   200 │   def _resolve_identity_cache(self, kwargs, cache, cache_key):                           │
# │   201 │   │   kwargs['identity_cache'] = cache                                                   │
# │                                                                                                  │
# │ /home/codespace/.python/current/lib/python3.12/site-packages/botocore/auth.py:424 in add_auth    │
# │                                                                                                  │
# │    421 │                                                                                         │
# │    422 │   def add_auth(self, request):                                                          │
# │    423 │   │   if self.credentials is None:                                                      │
# │ ❱  424 │   │   │   raise NoCredentialsError()                                                    │
# │    425 │   │   datetime_now = datetime.datetime.utcnow()                                         │
# │    426 │   │   request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)             │
# │    427 │   │   # This could be a retry.  Make sure the previous                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NoCredentialsError: Unable to locate credentials

# %%
download_from_s3('demo_file_from_s3.csv',s3_bucket_name,'data_format/demo_file.csv')

# %% [markdown]
# ## RecordIO Format
#
# We will use SageMaker SDK write_numpy_to_dense_tensor() method to create RecordIO files
#
#
# Data Types: Int32, Float32, Float64
#
# Reference:
# https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/amazon/common.py

# %%
df.head()

# %%
# X must be an array
X = df[['x1','x2','x3']].to_numpy()

# %%
X

# %%
type(X)

# %%
# Response/Target variable needs to a vector
# y must be a vector 
y = df[['y']].to_numpy()

# %%
# it is right now a array of dimensions 10x1
y.shape

# %%
y

# %%
# Flatten to a single dimension array of 10 elements
y = y.ravel()

# %%
y

# %%
def write_recordio_file (filename, x, y=None):
    with open(filename, 'wb') as f:
        smac.write_numpy_to_dense_tensor(f, x, y)

# %%
def read_recordio_file (filename, recordsToPrint = 10):
    with open(filename, 'rb') as f:
        record = smac.read_records(f)
        for i, r in enumerate(record):
            if i >= recordsToPrint:
                break
            print ("record: {}".format(i))
            print(r)

# %%
write_recordio_file('demo_file.recordio',X,y)

# %%
df.head(3)

# %%
read_recordio_file('demo_file.recordio',3)

# %%
write_to_s3('demo_file.recordio', s3_bucket_name, 'data_format/demo_file.recordio')

# %%
download_from_s3('demo_file_from_s3.recordio',s3_bucket_name,'data_format/demo_file.recordio')
